# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

data= requests.get("https://www.bizbaya.com/sme-india/Maharashtra/Mumbai")
soup= BeautifulSoup (data.text, 'html.parser')
table = soup.find_all('div',{'class':'views-field views-field-company-name'})
sme=[]
for i in table:
    name=i.text
    url="https://www.bizbaya.com" + i.find('a').attrs['href']
    print(name,url)
    sme.append([name,url])
# Out:
#  1-Up Clothing Co., Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/1-Up-Clothing-Co
#  3D Networks Pvt. Ltd., Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/3D-Networks-Pvt-Ltd
#  A G Technologies Pvt Ltd, Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/A-G-Technologies-Pvt-Ltd
#  A L M Engineering & Instrumentation Pvt. Ltd, Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/A-L-M-Engineering-Instrumentation-Pvt-Ltd
#  A-1 Industries, Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/A-1-Industries
#  A. I. M. Exports, Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/A-I-M-Exports
#  A. K. Impex, Mumbai, Maharashtra, Mumbai, Maharashtra  https://www.bizbaya.com/sme-india/Maharashtra/Mumbai/A-K-Impex
# ...

# %%
import pandas as pd
sme=pd.DataFrame(sme, columns=["Name","URL"])
sme

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
header = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/71.0.3578.98 Safari/537.36'}

data= requests.get("https://www.naukri.com/data-science-jobs", headers=header)
soup= BeautifulSoup (data.text, 'html.parser')
table = soup.find_all('div',{'class':'row'})
jobs=pd.DataFrame(columns=["Job Title","Location","Company Name","Experience Required","Skills Required","Job Description"])
#table

for i in table:
    try:
        title=i.find('a').text
    except:
        title="NA"
    try:
        loc=i.find(class_="loc").text
    except:
        loc="NA"
    try:
        exp=i.find(class_="exp").text
    except:
        exp="NA"
    try:
        org=i.find(class_="org").text
    except:
        org="NA"
    try:
        skill=i.find(class_="skill").text
    except:
        skill="NA"
    try:
        desc=i.find(class_="desc").text
    except:
        desc="NA"
    jobs=jobs.append({"Job Title":title,"Location":loc,"Company Name":org,"Experience Required":exp,"Skills Required":skill,"Job Description":desc}, ignore_index=True)

# %%
jobs.head(10)
# Out:
#                                            Job Title  \
# 0                                                 NA
# 1  Chief Intelligence Officer - Data Science & An...
# 2        Director - Data Science - B2B Product Setup
# 3            Director - Data Science - Product Setup
# 4  Data Scientist/ Data Science - KPO - IIT/ NIT/...
# 5  Data Engineer - Analytics & Data Science Platform
# 6  Engineering Manager (Web Technologies/ Data Sc...
# 7        Data Science Developer - Analytics/ Alteryx
# 8  Opening for Data Science Architect (AI Archite...
# 9  Internship - Artificial Intelligence, Machine ...
#
#                                 Location  \
# 0                                     NA
# 1  Delhi NCR, Mumbai, Bengaluru, Gurgaon
# 2                            Delhi, Pune
# 3                                  Delhi
# 4                              Bengaluru
# 5                              Bengaluru
# 6                              Bengaluru
# 7                                 Mumbai
# ...
